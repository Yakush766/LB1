# %% [markdown]
# # Практическое задание 1
# ***Жирный текст***, *курсив*
# Список:
# - Пункт 1
# - Пункт 2
# 1. Пункт 1
# 2. Пункт 2

# %% [markdown]
# $$
# \mathcal{L}\{f(t)\} = \int_0^\infty e^{-st} f(t) \, dt
# $$

# %% [markdown]
# ![Танчик Кв2](attachment:7d1c6f46-d30b-4438-98a6-42fedf49d6f6.png)
